# %% [markdown]
# ### Quicksort

# %%
import sys
sys.setrecursionlimit(2**31-1)

# %%
def quick_sort(L,l,r): #to quicksort elements from L[l] to L[r]
  if r-l<=1:
    return(L)
  (pivot,lower,upper)=(L[l],l+1,l+1)
  for i in range(l+1,r):
    if L[i]>pivot:
      upper+=1
    else:
      (L[i],L[lower])=(L[lower],L[i])
      (lower,upper)=(lower+1,upper+1)
  (L[l],L[lower-1])=(L[lower-1],L[l])
  quick_sort(L,l,lower-1)
  quick_sort(L,lower,upper)
  return(L)

# %%
quick_sort([13,17,19,9,10,5,7],0,7)
# Out:
# [13, 5, 7, 9, 10, 17, 19]

# %% [markdown]
# GrPA

# %%
def DishPrepareOrder(order_list):
  dic={}
  order_list.sort()
  for i in range(1001,1010,1):
    dic[i]=0
  for j in order_list:
    dic[j]+=1
  l = list(set(dic.values()))
  l_=[]
  for i in range(len(l)-1,-1,-1):
    L=[]
    for j in range(1001,1010,1):
      if dic[j]==l[i] and dic[j]!=0:
        L.append(j)
    L.sort()
    l_.extend(L)
  return(l_)

# %%
DishPrepareOrder([1009,1009,1002,1002])
# Out:
# [1002, 1009]

# %%
for i in range(1001,1010,1):
  print(i)
# Out:
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009

# %%
class Stack():
  def __init__(self):
    self.stack = []
  def isempty(self):
    return self.stack==0
  def push(self,data):
    if data not in self.stack:
      return(self.stack.append(data))
      return True
    else:
      return False
  def pop(self):
    if not self.isempty():
      return self.stack.pop()
    else:
      return False
def applyop(op,var1,var2):
  if op=='+':
    return(int(var1)+int(var2))
  if op=='-':
    return(int(var1)-int(var2))
  if op=='*':
    return(int(var1)*int(var2))
  if op=='/':
    return(int(var1)/int(var2))
  if op=='**':
    return(int(var1)**int(var2))
stack = Stack()
def EvaluateExpression(l_):
  l = list(map(str, l_.split()))
  for i in range(len(l)):
    if l[i].isnumeric():
      stack.push(l[i])
    else:
      A = stack.pop()
      B = stack.pop()
      stack.push(applyop(l[i],B,A))
  return(stack.pop())

EvaluateExpression('3 7 + 12 2 - *')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-fb6b218b0b93> in <cell line: 40>()
#      38   return(stack.pop())
#      39
# ---> 40 EvaluateExpression('3 7 + 12 2 - *')
#      41
#
# <ipython-input-12-fb6b218b0b93> in EvaluateExpression(l_)
#      34     else:
#      35       A = stack.pop()
# ---> 36       B = stack.pop()
#      37       stack.push(applyop(l[i],B,A))
#      38   return(stack.pop())
#
# <ipython-input-12-fb6b218b0b93> in pop(self)
#      12   def pop(self):
#      13     if not self.isempty():
# ---> 14       return self.stack.pop()
#      15     else:
#      16       return False
#
# IndexError: pop from empty list

# %%
l = list(map(str, input().split()))
# Out:
# 1 2 * +

# %%
# Stack implementation
class Stack:

  # constructor for the Stack class
  def __init__(self):
    # initialise an empty list
    self.stack = []
    # self.stack = list() works the same way as above code

  # push the number into the stack
  def push(self, data):
    if data not in self.stack:
      self.stack.append(data)
      return True
    else:
      return False
  # remove the top element
  def pop(self):
    if len(self.stack) <= 0:
      return "Stack is empty!"
    else:
      return self.stack.pop()

  # returns the size of the element
  def size(self):
    return len(self.stack)

  # peek to see the top element
  def peek(self):
    return self.stack[-1]

  # to check if stck is empty
  def isEmpty(self):
    if len(self.stack) <= 0:
      return True
    else:
      return False

  # show the content of stack
  def show(self):
    return self.stack

# %%
l = list(map(str, input().split()))
print(l)
# Out:
# 1 + ** 3 -
# ['1', '+', '**', '3', '-']

# %%
class Stack:
    def __init__(self):
        self.stack = []

    def is_empty(self):
        return len(self.stack) == 0

    def push(self, data):
        self.stack.append(data)

    def pop(self):
        if not self.is_empty():
            return self.stack.pop()

    def evaluate_postfix(self, expression):
        tokens = expression.split()

        for token in tokens:
            if token.isdigit():
                self.push(int(token))
            else:
                operand2 = self.pop()
                operand1 = self.pop()

                if operand1 is None or operand2 is None:
                    return "Invalid expression"

                if token == '+':
                    result = operand1 + operand2
                elif token == '-':
                    result = operand1 - operand2
                elif token == '*':
                    result = operand1 * operand2
                elif token == '/':
                    result = operand1 / operand2
                else:
                    return "Invalid operator"

                self.push(result)

        if not self.is_empty():
            return self.pop()
        else:
            return "Invalid expression"


expression = "2 3 1 * + 9 -"
stack = Stack()
result = stack.evaluate_postfix(expression)
print(result)
# Out:
# -4

# %%
'''class Stack():
    def __init__(self):
        self.stack = []

    def isempty(self):
        return len(self.stack) == 0

    def push(self, data):
        self.stack.append(data)

    def pop(self):
        if not self.isempty():
            return self.stack.pop()
        else:
            return False

def applyop(op, var1, var2):
    if op == '+':
        return int(var1) + int(var2)
    elif op == '-':
        return int(var1) - int(var2)
    elif op == '*':
        return int(var1) * int(var2)
    elif op == '/':
        return int(var1) / int(var2)
    elif op == '**':
        return int(var1) ** int(var2)
    else:
        return None

def EvaluateExpression(l_):
    stack = Stack()
    l = list(map(str, l_.split()))

    for i in range(len(l)):
        if l[i].isnumeric():
            stack.push(l[i])
        else:
            A = stack.pop()
            B = stack.pop()
            stack.push(applyop(l[i], B, A))

    return stack.pop()
EvaluateExpression('3 7 + 12 2 - *')'''



class Stack():
  def __init__(self):
    self.stack = []
  def isempty(self):
    return self.stack==0
  def push(self,data):
      return(self.stack.append(data))
  def pop(self):
    if not self.isempty():
      return self.stack.pop()
    else:
      return False
def applyop(op,var1,var2):
  if op=='+':
    return(int(var1)+int(var2))
  if op=='-':
    return(int(var1)-int(var2))
  if op=='*':
    return(int(var1)*int(var2))
  if op=='/':
    return(int(var1)/int(var2))
  if op=='**':
    return(int(var1)**int(var2))
stack = Stack()
def EvaluateExpression(l_):
  l = list(map(str, l_.split()))
  for i in range(len(l)):
    if l[i].isnumeric():
      stack.push(l[i])
    else:
      A = stack.pop()
      B = stack.pop()
      stack.push(applyop(l[i],B,A))
  return(stack.pop())

EvaluateExpression('3 7 + 12 2 - *')
# Out:
# 100

# %%
class Node:
  def __init__(self,v=None):
    self.value = v
    self.next = None
    return
  def isempty(self):
    if self.value == None:
      return True
    else:
      return False
  def append(self,v):
    if self.isempty():
      self.value = v
    elif self.next == None:
      self.next = v
    else:
      self.next.append(v)
  def insert(self,v):
    if self.isempty():
      self.value = v
      return
    newnode = Node(v)
    (self.value,newnode.value)=(newnode.value,self.value)
    (self.next,newnode)=(newnode,self.next)
  def reverse(self, root):
    strp=''
    self.value = root
    while(self.next!=None):
      (self.value, self.next.value)=(self.next.value, self.value)
      self.next = self
    return self.value

# %%
l1 = Node()
l1.append(1)
print(l1.next)
# Out:
# None

# %%
l2 = Node()
l2.isempty()
# Out:
# True

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

    def reverse(self):
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev

    def display(self):
        current = self.head
        while current:
            print(current.data, end=" ")
            current = current.next
        print()

# Create a linked list
linked_list = LinkedList()
linked_list.append(1)
linked_list.append(2)
linked_list.append(3)
linked_list.append(4)
linked_list.append(5)

print("Original Linked List:")
linked_list.display()

# Reverse the linked list
linked_list.reverse()

print("Reversed Linked List:")
linked_list.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-24c1971c4994> in <cell line: 29>()
#      27 # Create a linked list
#      28 linked_list = LinkedList()
# ---> 29 linked_list.append(1)
#      30 linked_list.append(2)
#      31 linked_list.append(3)
#
# AttributeError: 'LinkedList' object has no attribute 'append'

# %%
l = list(input().split())
l.sort(reverse = True)
# Out:
# 1 2 3
